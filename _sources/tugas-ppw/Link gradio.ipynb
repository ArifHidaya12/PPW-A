# %% [markdown]
# Link Gradio

# %% [markdown]
# 1. Klasifikasi
#
# https://huggingface.co/spaces/arifhidaya123/Klasifikasi_logreg
#
# 2. Rangkuman berita
#
# https://huggingface.co/spaces/arifhidaya123/rangkuman_with_graph
#
# 3. Klasifikasi dengan SVD
#
# https://huggingface.co/spaces/arifhidaya123/klasifikasi_svd
